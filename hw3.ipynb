# %%
import os
import matplotlib.pyplot as plt
print (os.environ['CONDA_DEFAULT_ENV'])
# Out:
# KC_815

# %%
#running edited random class and dice rolls
# %run Random.py
random = Random()
#filling array of 1000 random 6-sided dice rolls
data = []
for x in range(1000):
    data.append(random.categorical(6))

# %%
#plotting dice rolls
#number of sides
n = 6
#empty events array
events = np.zeros(n)
#fill events array by dice roll
for x in data:
    events[x-1] += 1
roll_num = []
for y in range(n):
    roll_num.append(y+1)
plt.bar(roll_num,events,)
plt.ylim(0,200)
plt.title('1000 Dice Rolls')
plt.xlabel('Roll number')
plt.ylabel('number of times')
plt.show()
